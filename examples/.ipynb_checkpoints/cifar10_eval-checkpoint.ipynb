# %% [markdown]
# # Model evaluation and re-training with TransAxx on CIFAR10 dataset
#
# In this notebook you can evaluate different approximate multipliers on various models.
# You can also retrain the model for further accuracy improvement
#
# **Note**:
# * Currently, the quantization bitwidth supported is 8bit and supported layers are Conv2d and Linear
#
# * Please make sure you have run the installation steps first
#
# * This example notebook approximates Conv2d layers

# %%
from classification.utils import *
device = 'cuda'

# %% [markdown]
# ## Load dataset
#
# Set your path for the CIFAR10 dataset
#
# 'calib dataset' is created from a 10% sample of train data for calibration purposes

# %%
val_data, calib_data = cifar10_data_loader(data_path="/workspace/datasets/cifar10_data", batch_size=128)
# Out:
# Downloading https://cave.cs.toronto.edu/kriz/cifar-10-python.tar.gz to /workspace/datasets/cifar10_data/cifar-10-python.tar.gz
# 100%|█████████████████████████████████████████████████████████████████████████████| 170498071/170498071 [02:16<00:00, 1250683.17it/s]
# Extracting /workspace/datasets/cifar10_data/cifar-10-python.tar.gz to /workspace/datasets/cifar10_data
# Files already downloaded and verified

# %% [markdown]
# ## Select a pretrained model

# %%
# an example repo with cifar10 models. you can use your own (ref: https://github.com/chenyaofo/pytorch-cifar-models)
model = torch.hub.load("chenyaofo/pytorch-cifar-models", 'cifar10_repvgg_a0', pretrained=True).to(device)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/chenyaofo/pytorch-cifar-models/zipball/master" to /root/.cache/torch/hub/master.zip
# Downloading: "https://github.com/chenyaofo/pytorch-cifar-models/releases/download/repvgg/cifar10_repvgg_a0-ef08a50e.pt" to /root/.cache/torch/hub/checkpoints/cifar10_repvgg_a0-ef08a50e.pt
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 30.1M/30.1M [00:23<00:00, 1.32MB/s]

# %% [markdown]
# ## Optional: Evaluate default model

# %%
top1 = evaluate_cifar10(model, val_data, device = device)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 78/78 [00:02<00:00, 31.85it/s]
# 2.658395719001419
# Accuracy of the network on the 10000 test images: 94.3209 %

# %% [markdown]
# ## Initialize model with axx layers

# %%
# get conv2d layers to approximate
conv2d_layers = [(name, module) for name, module in model.named_modules() if (isinstance(module, torch.nn.Conv2d) or isinstance(module, AdaptConv2D)) and ("head" not in name and "reduction" not in name)]

# %%
len(conv2d_layers)
# Out:
# 44

# %%
# Initialize model with all required approximate multipliers for axx layers. 
# No explicit assignment needed; this step JIT compiles all upcoming multipliers

axx_list = [{'axx_mult' : 'mul8s_acc', 'axx_power' : 1.0, 'quant_bits' : 8, 'fake_quant' : False}]*len(conv2d_layers)
axx_list[3:4] = [{'axx_mult' : 'mul8s_1L2H', 'axx_power' : 0.7082, 'quant_bits' : 8, 'fake_quant' : False}] * 1

start = time.time()
replace_conv_layers(model,  AdaptConv2D, axx_list, 0, 0, layer_count=[0], returned_power = [0], initialize = True)  
print('Time to compile cuda extensions: ', time.time()-start)
# Out:
# Time to compile cuda extensions:  79.39271426200867

# %%
# measure flops of model and compute 'flops' in every layer

import io
from classification.ptflops import get_model_complexity_info
from classification.ptflops.pytorch_ops import linear_flops_counter_hook
from classification.ptflops.pytorch_ops import conv_flops_counter_hook

#hook our custom axx_layers in the appropriate flop counters, i.e. AdaptConv2D : conv_flops_counter_hook
with torch.cuda.device(0):
    total_macs, total_params, layer_specs = get_model_complexity_info(model, (3, 32, 32),as_strings=False, print_per_layer_stat=True,
                                                          custom_modules_hooks={AdaptConv2D : conv_flops_counter_hook}, 
                                                          param_units='M', flops_units='MMac',
                                                          verbose=True)

print(f'Computational complexity:  {total_macs/1000000:.2f} MMacs')
print(f'Number of parameters::  {total_params/1000000:.2f} MParams')
# Out:
# Warning: module TensorQuantizer is treated as a zero-op.
# Warning: module RepVGGBlock is treated as a zero-op.
# Warning: module RepVGG is treated as a zero-op.
# Computational complexity:  491.95 MMacs
# Number of parameters::  7.84 MParams

# %% [markdown]
# ## Run model calibration for quantization
#
# Calibrates the quantization parameters
#
# Need to re-run it each time the initial model changes

# %%
with torch.no_grad():
    stats = collect_stats(model, calib_data, num_batches=2, device=device)
    amax = compute_amax(model, method="percentile", percentile=99.99, device=device)
    
    # optional - test different calibration methods
    #amax = compute_amax(model, method="mse")
    #amax = compute_amax(model, method="entropy")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:16<00:00,  8.22s/it]
# WARNING: Logging before flag parsing goes to stderr.
# W0618 16:51:59.385526 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.385959 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.386133 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.386264 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.386404 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.386537 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.386846 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387020 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387185 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387300 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387419 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387539 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387656 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387773 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.387895 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388016 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388135 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388247 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388368 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388481 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388599 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388747 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.388925 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389059 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389182 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389291 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389408 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389527 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389637 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389754 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389871 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.389992 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.390812 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.390947 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391077 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391201 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391330 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391450 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391576 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391709 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.391835 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392036 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392226 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392358 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392488 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392617 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392759 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.392928 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393148 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393301 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393448 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393596 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393728 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393850 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.393983 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.394096 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.394216 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.394385 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.394522 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.394674 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.394857 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.395085 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.395237 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.395382 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.396450 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.396597 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.396723 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.396872 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.397012 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.397129 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.397252 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.397584 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.397751 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.397874 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.398002 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.398124 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.398253 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.399194 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.399363 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.399581 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.399755 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.399914 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.400066 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.400201 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.400343 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.400506 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.400693 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.400914 138437272064640 tensor_quantizer.py:173] Disable HistogramCalibrator
# W0618 16:51:59.401582 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.401742 138437272064640 tensor_quantizer.py:238] Call .cuda() if running on GPU after loading calibrated amax.
# W0618 16:51:59.402111 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.402498 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.402725 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.403036 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.403240 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.403507 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.403704 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.403904 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.404209 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.404454 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.404639 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.404995 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.405343 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.405622 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.405997 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.406260 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.406528 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.406794 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.407423 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.407655 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.407862 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.408077 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.408265 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.408455 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.408643 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.408839 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.409383 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.409575 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.409757 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.409950 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.410138 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.410504 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.410691 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.410969 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.411200 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.411394 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.411576 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.411850 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.412058 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.412303 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.412486 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.412662 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.412953 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.413187 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.413371 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.413625 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.413802 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.414060 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.414244 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.414424 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.414595 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.414770 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.415096 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.415270 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.415529 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.415709 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.415886 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.416182 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.416407 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.416586 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.416757 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.416950 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.417524 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.417875 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.418240 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.418733 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.418981 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.419385 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.419621 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.419948 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.420212 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.420476 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.420703 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.420919 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.421149 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.421470 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.421702 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.421952 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.422146 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.422337 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.422516 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.422844 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.423038 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.423290 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.423473 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.423658 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# W0618 16:51:59.423965 138437272064640 tensor_quantizer.py:237] Load calibrated amax, shape=torch.Size([]).
# stage0.rbr_dense.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=2.1255 calibrator=HistogramCalibrator scale=1.0 quant)
# stage0.rbr_dense.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.3628 calibrator=HistogramCalibrator scale=349.8851318359375 quant)
# stage0.rbr_1x1.conv.quantizer           : TensorQuantizer(8bit per-tensor amax=2.1255 calibrator=HistogramCalibrator scale=1.0 quant)
# stage0.rbr_1x1.conv.quantizer_w         : TensorQuantizer(8bit per-tensor amax=0.4948 calibrator=HistogramCalibrator scale=256.5318603515625 quant)
# stage1.0.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.1008 calibrator=HistogramCalibrator scale=419.8192138671875 quant)
# stage1.0.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.1891 calibrator=HistogramCalibrator scale=623.5847778320312 quant)
# stage1.0.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.1008 calibrator=HistogramCalibrator scale=419.8192138671875 quant)
# stage1.0.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.2498 calibrator=HistogramCalibrator scale=508.22552490234375 quant)
# stage1.1.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.5493 calibrator=HistogramCalibrator scale=0.001299710595048964 quant)
# stage1.1.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.1906 calibrator=HistogramCalibrator scale=547.1300659179688 quant)
# stage1.1.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.5493 calibrator=HistogramCalibrator scale=0.001299710595048964 quant)
# stage1.1.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.2335 calibrator=HistogramCalibrator scale=543.671875 quant)
# stage2.0.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.7485 calibrator=HistogramCalibrator scale=0.0009104527998715639 quant)
# stage2.0.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.1353 calibrator=HistogramCalibrator scale=793.5965576171875 quant)
# stage2.0.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.7485 calibrator=HistogramCalibrator scale=0.0009104527998715639 quant)
# stage2.0.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.1574 calibrator=HistogramCalibrator scale=806.3528442382812 quant)
# stage2.1.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=0.7757 calibrator=HistogramCalibrator scale=0.0019296294776722789 quant)
# stage2.1.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0746 calibrator=HistogramCalibrator scale=1353.4476318359375 quant)
# stage2.1.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=0.7757 calibrator=HistogramCalibrator scale=0.0019296294776722789 quant)
# stage2.1.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0735 calibrator=HistogramCalibrator scale=1728.2066650390625 quant)
# stage2.2.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.2121 calibrator=HistogramCalibrator scale=0.0011157399276271462 quant)
# stage2.2.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0845 calibrator=HistogramCalibrator scale=1104.7998046875 quant)
# stage2.2.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.2121 calibrator=HistogramCalibrator scale=0.0011157399276271462 quant)
# stage2.2.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0931 calibrator=HistogramCalibrator scale=1364.03125 quant)
# stage2.3.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.4875 calibrator=HistogramCalibrator scale=0.0005209675873629749 quant)
# stage2.3.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0994 calibrator=HistogramCalibrator scale=903.7467041015625 quant)
# stage2.3.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.4875 calibrator=HistogramCalibrator scale=0.0005209675873629749 quant)
# stage2.3.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.1354 calibrator=HistogramCalibrator scale=937.5003051757812 quant)
# stage3.0.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.6484 calibrator=HistogramCalibrator scale=0.0003970199031755328 quant)
# stage3.0.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.1005 calibrator=HistogramCalibrator scale=740.3419799804688 quant)
# stage3.0.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.6484 calibrator=HistogramCalibrator scale=0.0003970199031755328 quant)
# stage3.0.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0875 calibrator=HistogramCalibrator scale=1036.6353759765625 quant)
# stage3.1.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=0.6895 calibrator=HistogramCalibrator scale=0.000951406720560044 quant)
# stage3.1.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0481 calibrator=HistogramCalibrator scale=1755.15380859375 quant)
# stage3.1.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=0.6895 calibrator=HistogramCalibrator scale=0.000951406720560044 quant)
# stage3.1.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0500 calibrator=HistogramCalibrator scale=2334.70654296875 quant)
# stage3.2.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=0.9855 calibrator=HistogramCalibrator scale=0.00045488475007005036 quant)
# stage3.2.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0503 calibrator=HistogramCalibrator scale=1733.7703857421875 quant)
# stage3.2.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=0.9855 calibrator=HistogramCalibrator scale=0.00045488475007005036 quant)
# stage3.2.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0478 calibrator=HistogramCalibrator scale=2062.927734375 quant)
# stage3.3.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.2430 calibrator=HistogramCalibrator scale=0.0007393453852273524 quant)
# stage3.3.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0590 calibrator=HistogramCalibrator scale=1473.2110595703125 quant)
# stage3.3.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.2430 calibrator=HistogramCalibrator scale=0.0007393453852273524 quant)
# stage3.3.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0419 calibrator=HistogramCalibrator scale=2603.29345703125 quant)
# stage3.4.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.2946 calibrator=HistogramCalibrator scale=0.0004984228871762753 quant)
# stage3.4.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0610 calibrator=HistogramCalibrator scale=1127.9583740234375 quant)
# stage3.4.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.2946 calibrator=HistogramCalibrator scale=0.0004984228871762753 quant)
# stage3.4.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0491 calibrator=HistogramCalibrator scale=2113.308349609375 quant)
# stage3.5.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.3736 calibrator=HistogramCalibrator scale=0.0005940690753050148 quant)
# stage3.5.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0622 calibrator=HistogramCalibrator scale=1322.8944091796875 quant)
# stage3.5.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.3736 calibrator=HistogramCalibrator scale=0.0005940690753050148 quant)
# stage3.5.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0474 calibrator=HistogramCalibrator scale=2299.19873046875 quant)
# stage3.6.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.3061 calibrator=HistogramCalibrator scale=0.0007017696625553071 quant)
# stage3.6.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0542 calibrator=HistogramCalibrator scale=1451.494140625 quant)
# stage3.6.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.3061 calibrator=HistogramCalibrator scale=0.0007017696625553071 quant)
# stage3.6.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0357 calibrator=HistogramCalibrator scale=3030.50634765625 quant)
# stage3.7.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.3801 calibrator=HistogramCalibrator scale=0.00033015524968504906 quant)
# stage3.7.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0540 calibrator=HistogramCalibrator scale=1474.31591796875 quant)
# stage3.7.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.3801 calibrator=HistogramCalibrator scale=0.00033015524968504906 quant)
# stage3.7.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0291 calibrator=HistogramCalibrator scale=3242.998046875 quant)
# stage3.8.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.4540 calibrator=HistogramCalibrator scale=0.00046310710604302585 quant)
# stage3.8.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0540 calibrator=HistogramCalibrator scale=1615.5277099609375 quant)
# stage3.8.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.4540 calibrator=HistogramCalibrator scale=0.00046310710604302585 quant)
# stage3.8.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0266 calibrator=HistogramCalibrator scale=3954.505615234375 quant)
# stage3.9.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.5522 calibrator=HistogramCalibrator scale=0.0003686116251628846 quant)
# stage3.9.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0534 calibrator=HistogramCalibrator scale=1125.8734130859375 quant)
# stage3.9.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.5522 calibrator=HistogramCalibrator scale=0.0003686116251628846 quant)
# stage3.9.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0524 calibrator=HistogramCalibrator scale=1659.3878173828125 quant)
# stage3.10.rbr_dense.conv.quantizer      : TensorQuantizer(8bit per-tensor amax=1.5607 calibrator=HistogramCalibrator scale=0.0008287421660497785 quant)
# stage3.10.rbr_dense.conv.quantizer_w    : TensorQuantizer(8bit per-tensor amax=0.0418 calibrator=HistogramCalibrator scale=1839.17333984375 quant)
# stage3.10.rbr_1x1.conv.quantizer        : TensorQuantizer(8bit per-tensor amax=1.5607 calibrator=HistogramCalibrator scale=0.0008287421660497785 quant)
# stage3.10.rbr_1x1.conv.quantizer_w      : TensorQuantizer(8bit per-tensor amax=0.0228 calibrator=HistogramCalibrator scale=4612.30712890625 quant)
# stage3.11.rbr_dense.conv.quantizer      : TensorQuantizer(8bit per-tensor amax=1.5381 calibrator=HistogramCalibrator scale=0.00047514057951048017 quant)
# stage3.11.rbr_dense.conv.quantizer_w    : TensorQuantizer(8bit per-tensor amax=0.0397 calibrator=HistogramCalibrator scale=1487.13720703125 quant)
# stage3.11.rbr_1x1.conv.quantizer        : TensorQuantizer(8bit per-tensor amax=1.5381 calibrator=HistogramCalibrator scale=0.00047514057951048017 quant)
# stage3.11.rbr_1x1.conv.quantizer_w      : TensorQuantizer(8bit per-tensor amax=0.0241 calibrator=HistogramCalibrator scale=4610.83935546875 quant)
# stage3.12.rbr_dense.conv.quantizer      : TensorQuantizer(8bit per-tensor amax=1.4459 calibrator=HistogramCalibrator scale=0.0006209207931533456 quant)
# stage3.12.rbr_dense.conv.quantizer_w    : TensorQuantizer(8bit per-tensor amax=0.0377 calibrator=HistogramCalibrator scale=2066.015869140625 quant)
# stage3.12.rbr_1x1.conv.quantizer        : TensorQuantizer(8bit per-tensor amax=1.4459 calibrator=HistogramCalibrator scale=0.0006209207931533456 quant)
# stage3.12.rbr_1x1.conv.quantizer_w      : TensorQuantizer(8bit per-tensor amax=0.0213 calibrator=HistogramCalibrator scale=3852.668701171875 quant)
# stage3.13.rbr_dense.conv.quantizer      : TensorQuantizer(8bit per-tensor amax=1.1398 calibrator=HistogramCalibrator scale=0.004640911240130663 quant)
# stage3.13.rbr_dense.conv.quantizer_w    : TensorQuantizer(8bit per-tensor amax=0.0353 calibrator=HistogramCalibrator scale=2128.9443359375 quant)
# stage3.13.rbr_1x1.conv.quantizer        : TensorQuantizer(8bit per-tensor amax=1.1398 calibrator=HistogramCalibrator scale=0.004640911240130663 quant)
# stage3.13.rbr_1x1.conv.quantizer_w      : TensorQuantizer(8bit per-tensor amax=0.0216 calibrator=HistogramCalibrator scale=5691.36474609375 quant)
# stage4.0.rbr_dense.conv.quantizer       : TensorQuantizer(8bit per-tensor amax=1.2038 calibrator=HistogramCalibrator scale=0.002594488440081477 quant)
# stage4.0.rbr_dense.conv.quantizer_w     : TensorQuantizer(8bit per-tensor amax=0.0085 calibrator=HistogramCalibrator scale=9720.8115234375 quant)
# stage4.0.rbr_1x1.conv.quantizer         : TensorQuantizer(8bit per-tensor amax=1.2038 calibrator=HistogramCalibrator scale=0.002594488440081477 quant)
# stage4.0.rbr_1x1.conv.quantizer_w       : TensorQuantizer(8bit per-tensor amax=0.0174 calibrator=HistogramCalibrator scale=5896.40283203125 quant)

# %% [markdown]
# ## Run model evaluation

# %%
# set desired approximate multiplier in each layer

#at first, set all layers to have the 8-bit accurate multiplier
axx_list = [{'axx_mult' : 'mul8s_acc', 'axx_power' : 1.0, 'quant_bits' : 8, 'fake_quant' : False}]*len(conv2d_layers)

# For example, set the first 10 layers to be approximated with a specific multiplier 
axx_list[0:10] = [{'axx_mult' : 'mul8s_1L2H', 'axx_power' : 0.7082, 'quant_bits' : 8, 'fake_quant' : False}] * 10

returned_power = [0]
replace_conv_layers(model,  AdaptConv2D, axx_list, total_macs, total_params, layer_count=[0], returned_power = returned_power, initialize = False)  
print('Power of approximated operations: ', round(returned_power[0], 2), '%')
print('Model compiled. Running evaluation')

# Run evaluation on the validation dataset
top1 = evaluate_cifar10(model, val_data, device = device)
# Out:
# Power of approximated operations:  94.43 %
# Model compiled. Running evaluation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 78/78 [00:21<00:00,  3.61it/s]
# 21.926636146992678
# Accuracy of the network on the 10000 test images: 91.7067 %

# %% [markdown]
# ## Run model retraining

# %%
from classification.train import train_one_epoch

criterion = torch.nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001) # set desired learning rate
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.1)

#one epoch retrain
epochs = 50
for epoch in range(epochs):
    print("strart epoch")
    train_one_epoch(model, criterion, optimizer, calib_data, device, 0, 10)
print("end retraining")
# Out:
# strart epoch
# Epoch: [0]  [ 0/39]  eta: 0:00:29  lr: 0.0001  img/s: 339.38209515477206  loss: 0.0669 (0.0669)  acc1: 97.6562 (97.6562)  acc5: 100.0000 (100.0000)  time: 0.7497  data: 0.3726  max mem: 822
# Epoch: [0]  [10/39]  eta: 0:00:10  lr: 0.0001  img/s: 380.4500254048657  loss: 0.0761 (0.0775)  acc1: 97.6562 (97.5142)  acc5: 100.0000 (99.8580)  time: 0.3748  data: 0.0340  max mem: 822
# Epoch: [0]  [20/39]  eta: 0:00:06  lr: 0.0001  img/s: 379.94276983307515  loss: 0.0706 (0.0723)  acc1: 97.6562 (97.6562)  acc5: 100.0000 (99.8512)  time: 0.3382  data: 0.0001  max mem: 822
# Epoch: [0]  [30/39]  eta: 0:00:03  lr: 0.0001  img/s: 380.73277975518033  loss: 0.0658 (0.0731)  acc1: 97.6562 (97.7319)  acc5: 100.0000 (99.8236)  time: 0.3386  data: 0.0001  max mem: 822
# Epoch: [0] Total time: 0:00:13
# strart epoch
# Epoch: [0]  [ 0/39]  eta: 0:00:26  lr: 0.0001  img/s: 376.0195325030432  loss: 0.0636 (0.0636)  acc1: 98.4375 (98.4375)  acc5: 100.0000 (100.0000)  time: 0.6795  data: 0.3391  max mem: 822
# Epoch: [0]  [10/39]  eta: 0:00:10  lr: 0.0001  img/s: 377.9966514258195  loss: 0.0730 (0.0736)  acc1: 97.6562 (97.6562)  acc5: 100.0000 (99.8580)  time: 0.3688  data: 0.0309  max mem: 822
# Epoch: [0]  [20/39]  eta: 0:00:06  lr: 0.0001  img/s: 379.53450388144364  loss: 0.0686 (0.0681)  acc1: 97.6562 (97.8051)  acc5: 100.0000 (99.8512)  time: 0.3386  data: 0.0001  max mem: 822
# Epoch: [0]  [30/39]  eta: 0:00:03  lr: 0.0001  img/s: 378.08396468114296  loss: 0.0592 (0.0691)  acc1: 97.6562 (97.8327)  acc5: 100.0000 (99.8236)  time: 0.3395  data: 0.0001  max mem: 822
# Epoch: [0] Total time: 0:00:13
# strart epoch
# Epoch: [0]  [ 0/39]  eta: 0:00:26  lr: 0.0001  img/s: 377.73415615217976  loss: 0.0567 (0.0567)  acc1: 98.4375 (98.4375)  acc5: 100.0000 (100.0000)  time: 0.6834  data: 0.3446  max mem: 822
# Epoch: [0]  [10/39]  eta: 0:00:10  lr: 0.0001  img/s: 379.73745274244146  loss: 0.0645 (0.0688)  acc1: 97.6562 (97.7983)  acc5: 100.0000 (99.8580)  time: 0.3697  data: 0.0314  max mem: 822
# Epoch: [0]  [20/39]  eta: 0:00:06  lr: 0.0001  img/s: 378.81679980186715  loss: 0.0638 (0.0638)  acc1: 97.6562 (97.9911)  acc5: 100.0000 (99.8512)  time: 0.3388  data: 0.0001  max mem: 822
# Epoch: [0]  [30/39]  eta: 0:00:03  lr: 0.0001  img/s: 379.8102557862477  loss: 0.0560 (0.0651)  acc1: 98.4375 (98.0847)  acc5: 100.0000 (99.8236)  time: 0.3394  data: 0.0001  max mem: 822
# Epoch: [0] Total time: 0:00:13
# strart epoch
# Epoch: [0]  [ 0/39]  eta: 0:00:26  lr: 0.0001  img/s: 376.350604759281  loss: 0.0507 (0.0507)  acc1: 98.4375 (98.4375)  acc5: 100.0000 (100.0000)  time: 0.6800  data: 0.3399  max mem: 822
# Epoch: [0]  [10/39]  eta: 0:00:10  lr: 0.0001  img/s: 379.20584385817824  loss: 0.0614 (0.0648)  acc1: 97.6562 (97.9403)  acc5: 100.0000 (99.8580)  time: 0.3697  data: 0.0310  max mem: 822
# Epoch: [0]  [20/39]  eta: 0:00:06  lr: 0.0001  img/s: 376.8374625791847  loss: 0.0610 (0.0604)  acc1: 97.6562 (98.0655)  acc5: 100.0000 (99.8512)  time: 0.3394  data: 0.0001  max mem: 822
# Epoch: [0]  [30/39]  eta: 0:00:03  lr: 0.0001  img/s: 379.1305949332584  loss: 0.0542 (0.0618)  acc1: 98.4375 (98.1855)  acc5: 100.0000 (99.8236)  time: 0.3399  data: 0.0001  max mem: 822
# Epoch: [0] Total time: 0:00:13
# strart epoch
# Epoch: [0]  [ 0/39]  eta: 0:00:26  lr: 0.0001  img/s: